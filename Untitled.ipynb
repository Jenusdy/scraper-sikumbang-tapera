# %%
import requests
import pandas as pd
import time
import configparser
import mysql.connector
from mysql.connector import Error

# %%
# =========================
# READ CONFIG
# =========================
config = configparser.ConfigParser()
config.read("config.ini")

db_config = {
    "host": config["database"]["host"],
    "user": config["database"]["user"],
    "password": config["database"]["password"],
    "database": config["database"]["database"]
}

# =========================
# MYSQL CONNECTION
# =========================
conn = mysql.connector.connect(**db_config)
cursor = conn.cursor()

# %%
def scrape_sikumbang_all_data(limit_per_page=100):
    search_url = "https://sikumbang.tapera.go.id/ajax/lokasi/search"

    headers = {
        "User-Agent": "Mozilla/5.0",
        "Referer": "https://sikumbang.tapera.go.id/",
        "X-Requested-With": "XMLHttpRequest"
    }

    page_number = 1
    all_rows = []

    print("Memulai scraping data...")

    while True:
        params = {
            "sort": "terbaru",
            "page": page_number,
            "limit": limit_per_page
        }

        print(f"[INFO] Halaman {page_number}")

        try:
            response = requests.get(
                search_url,
                params=params,
                headers=headers,
                timeout=15
            )

            response.raise_for_status()

            data_list = response.json().get("data", [])

            if not data_list:
                print("Semua halaman selesai.")
                break

            for lokasi in data_list:

                id_lokasi = lokasi.get("idLokasi")

                detail_url = f"https://sikumbang.tapera.go.id/lokasi-perumahan/{id_lokasi}/json"

                try:
                    detail_resp = requests.get(
                        detail_url,
                        headers=headers,
                        timeout=10
                    )

                    if detail_resp.status_code != 200:
                        continue

                    detail_json = detail_resp.json()

                    detail_info = detail_json.get("detail", {})

                    kantor_list = detail_info.get("kantorPemasaran", [])
                    kontak_utama = kantor_list[0] if kantor_list else {}

                    bangunan_list = detail_json.get("bangunan", [])

                    # =========================
                    # AGREGASI UNIT
                    # =========================
                    jml_subsidi = 0
                    jml_subsidi_terjual = 0
                    jml_komersil = 0
                    jml_komersil_terjual = 0

                    for bgn in bangunan_list:
                        tipe_bgn = str(bgn.get("tipeBangunan")).lower()
                        status_unit = str(bgn.get("status")).lower()

                        if tipe_bgn == "subsidi":
                            jml_subsidi += 1

                            if status_unit == "terjual":
                                jml_subsidi_terjual += 1

                        elif tipe_bgn == "komersil":
                            jml_komersil += 1

                            if status_unit == "komersil-terjual":
                                jml_komersil_terjual += 1

                    info_lokasi = {
                        "id_lokasi": id_lokasi,
                        "nama_perumahan": detail_info.get("namaPerumahan"),
                        "alamat": kontak_utama.get("alamat"),
                        "telpon": kontak_utama.get("noTelp"),
                        "email": kontak_utama.get("email"),
                        "website": kontak_utama.get("website"),

                        "provinsi": detail_info.get("wilayah", {}).get("provinsi"),
                        "kabupaten": detail_info.get("wilayah", {}).get("kabupaten"),
                        "kecamatan": detail_info.get("wilayah", {}).get("kecamatan"),

                        "koordinat": detail_info.get("koordinatPerumahan"),

                        "pengembang": detail_info.get("pengembang", {}).get("nama"),

                        "jumlah_unit_subsidi": jml_subsidi,
                        "jumlah_unit_subsidi_terjual": jml_subsidi_terjual,
                        "jumlah_unit_komersil": jml_komersil,
                        "jumlah_unit_komersil_terjual": jml_komersil_terjual
                    }

                    # =========================
                    # INSERT DATABASE
                    # =========================
                    insert_query = """
                    INSERT INTO sikumbang_tapera (
                        id_lokasi,
                        nama_perumahan,
                        alamat,
                        telpon,
                        email,
                        website,
                        provinsi,
                        kabupaten,
                        kecamatan,
                        koordinat,
                        pengembang,
                        jumlah_unit_subsidi,
                        jumlah_unit_subsidi_terjual,
                        jumlah_unit_komersil,
                        jumlah_unit_komersil_terjual,
                        id_rumah,
                        blok,
                        nomor_rumah,
                        tipe_bangunan,
                        status_unit,
                        npwp_MK,
                        nik_pemilik,
                        nik_booking,
                        tanggal_terjual,
                        nama_tipe,
                        harga,
                        luas_bangunan,
                        luas_lahan,
                        kamar_tidur,
                        kamar_mandi,
                        atap,
                        dinding,
                        lantai,
                        pondasi,
                        createdAt,
                        updatedAt,
                        tahun
                    )
                    VALUES (
                        # %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
                        # %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
                        # %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
                        # %s,%s,%s,%s,%s,%s,%s
                    )
                    """

                    for bgn in bangunan_list:

                        tipe = bgn.get("tipe", {})

                        created_at_raw = tipe.get("createdAt")

                        created_at = pd.to_datetime(
                            created_at_raw,
                            errors="coerce"
                        )

                        updated_at = pd.to_datetime(
                            tipe.get("updatedAt"),
                            errors="coerce"
                        )

                        tanggal_terjual = pd.to_datetime(
                            bgn.get("tanggalTerjual"),
                            errors="coerce"
                        )

                        values = (
                            info_lokasi["id_lokasi"],
                            info_lokasi["nama_perumahan"],
                            info_lokasi["alamat"],
                            info_lokasi["telpon"],
                            info_lokasi["email"],
                            info_lokasi["website"],

                            info_lokasi["provinsi"],
                            info_lokasi["kabupaten"],
                            info_lokasi["kecamatan"],

                            info_lokasi["koordinat"],

                            info_lokasi["pengembang"],

                            info_lokasi["jumlah_unit_subsidi"],
                            info_lokasi["jumlah_unit_subsidi_terjual"],
                            info_lokasi["jumlah_unit_komersil"],
                            info_lokasi["jumlah_unit_komersil_terjual"],

                            bgn.get("idRumah"),

                            bgn.get("blok", {}).get("blok")
                            if bgn.get("blok")
                            else None,

                            bgn.get("nomor"),

                            bgn.get("tipeBangunan"),
                            bgn.get("status"),

                            bgn.get("npwpMK"),
                            bgn.get("nikPemilik"),
                            bgn.get("nikBooking"),

                            tanggal_terjual.date()
                            if not pd.isna(tanggal_terjual)
                            else None,

                            tipe.get("nama"),

                            tipe.get("harga"),

                            tipe.get("luasBangunan"),
                            tipe.get("luasTanah"),

                            tipe.get("kamarTidur"),
                            tipe.get("kamarMandi"),

                            tipe.get("spesifikasiAtap"),
                            tipe.get("spesifikasiDinding"),
                            tipe.get("spesifikasiLantai"),
                            tipe.get("spesifikasiPondasi"),

                            created_at.date()
                            if not pd.isna(created_at)
                            else None,

                            updated_at.date()
                            if not pd.isna(updated_at)
                            else None,

                            created_at.year
                            if not pd.isna(created_at)
                            else None
                        )

                        cursor.execute(insert_query, values)

                    conn.commit()

                    print(
                        f"SUCCESS -> {info_lokasi['nama_perumahan']} "
                        f"({len(bangunan_list)} unit)"
                    )

                    time.sleep(0.5)

                except Exception as e:
                    print(f"Gagal detail lokasi {id_lokasi}: {e}")

            page_number += 1

        except Exception as e:
            print(f"Gagal halaman {page_number}: {e}")
            break

# %%
# =========================
# RUN SCRAPER
# =========================
scrape_sikumbang_all_data(limit_per_page=100)

# =========================
# CLOSE CONNECTION
# =========================
cursor.close()
conn.close()

print("Selesai.")
# Out:
# Memulai scraping data...
# [INFO] Halaman 1
# SUCCESS -> PERUMAHAN ATLANTIC 99 TAHAP II (77 unit)
# SUCCESS -> GIA EDELWEISS 3 (185 unit)
# SUCCESS -> KARANGSARI RESIDENCE (76 unit)
# SUCCESS -> HARJITA LIVING 2 (163 unit)
# SUCCESS -> RAN SHAQUEENA RESIDENT TAHAP IV (104 unit)
# SUCCESS -> BUMI ASA GEMILANG (53 unit)
# SUCCESS -> GRAHA KHAYANGAN HILLS IV (125 unit)
# SUCCESS -> THE HALONA TAMANYELENG (28 unit)
# SUCCESS -> GREEN NARAYA RESIDENCE (32 unit)
# SUCCESS -> Tirta Harmoni (40 unit)
# SUCCESS -> GRIYA KHALISA 3 (0 unit)
# SUCCESS -> Banteng Residence D (113 unit)
# SUCCESS -> ANAIWOI VILLAGE RESIDENCE II (52 unit)
# SUCCESS -> BUKIT MUTIARA ESTATE (5 unit)
# SUCCESS -> WMP9 SUTARTI (108 unit)
# SUCCESS -> Griya Sakinah 2 (3 unit)
# SUCCESS -> CITRA PERMATA 3 (87 unit)
# SUCCESS -> GRIYA ARYALOKA SUKOREJO (149 unit)
# SUCCESS -> ARSOL LAND TAHAP 2 (75 unit)
# SUCCESS -> GRAHA PERINTIS PERMAI II (31 unit)
# SUCCESS -> BTN AIK DAREK INDAH (91 unit)
# SUCCESS -> GRIYA CITRA LEPO-LEPO (5 unit)
# SUCCESS -> GRIIYA TAMAN KAKTUS CLUSTER B (124 unit)
# SUCCESS -> PERMATA CITRA RESIDENCE (110 unit)
# SUCCESS -> GRAND AZKIA ZAMZAM (33 unit)
# SUCCESS -> ERLANGGA MEGA RESIDENCE - BUKIT SULAA (95 unit)
# SUCCESS -> GRAHA STAVIA (43 unit)
# SUCCESS -> Permata Indah 2 (7 unit)
# SUCCESS -> SUKASARI RESIDENCE (2 unit)
# SUCCESS -> WMP HAPPY BARAT (38 unit)
# SUCCESS -> Griya Indah (53 unit)
# SUCCESS -> KALUNA UTAMA RESIDENCE (81 unit)
# SUCCESS -> GRIYA ANUGERAH 1 (23 unit)
# SUCCESS -> BINTANG REGENCY IV (68 unit)
# SUCCESS -> ISABELLA RESIDENCE (90 unit)
# SUCCESS -> AZFAR INDAH 2 (8 unit)
# SUCCESS -> LARUMBALANGI RESIDENCE (57 unit)
# SUCCESS -> GRIYA ANGGREK PERMAI (65 unit)
# SUCCESS -> ROMEBY PEA LESTARI (126 unit)
# SUCCESS -> PURI ALISYA ASRI (197 unit)
# SUCCESS -> GRIYA MUSI (9 unit)
# SUCCESS -> Bukit Sampuraga Baru 3 (90 unit)
# SUCCESS -> NADHIFA LAND (36 unit)
# SUCCESS -> GREEN MANSION FATRIDA/TAHAP 4 (2 unit)
# SUCCESS -> Ayyubi Madani (21 unit)
# SUCCESS -> THE HIGHLAND SINGHASARI RESIDENCE (177 unit)
# SUCCESS -> SINAR BERKAH TINELO (41 unit)
# SUCCESS -> perum Griya Tatar Sunda (21 unit)
# SUCCESS -> Mavilla Bantarwaru 2 (12 unit)
# SUCCESS -> MELODY MAKMUR RESIDENCE (19 unit)
# SUCCESS -> GRAHA ARSY SEJAHTERA 2 (0 unit)
# SUCCESS -> Griya Darul Taqwa (73 unit)
# SUCCESS -> HANIN RESIDENT 142 (43 unit)
# SUCCESS -> PERUMAHAN BANUA INDAH PERMAI CLUSTER PALEM 2 TAHAP 2 (28 unit)
# SUCCESS -> GRAND ALIM RESIDENCE TAHAP III (119 unit)
# SUCCESS -> Montana Sinergia (49 unit)
# SUCCESS -> Grand Savana Residence (40 unit)
# SUCCESS -> KHARISMA CAHAYA RESIDENCE 2 (0 unit)
# SUCCESS -> GRIYA MORI CENDRAWASIH (44 unit)
# SUCCESS -> ASTANA SABRANG (50 unit)
# SUCCESS -> Wanaking's Garden (75 unit)
# SUCCESS -> GRIYA SAFIRA RESINDENCE (70 unit)
# SUCCESS -> MISHA RESIDENCE (124 unit)
# SUCCESS -> PURI KOSAMBI 1&2 (1 unit)
# SUCCESS -> CEMERLANG ASRI 21 (8 unit)
# SUCCESS -> Sokkolia Pratama Land (57 unit)
# SUCCESS -> BARUNIA HOMELY TAHAP IV (82 unit)
# SUCCESS -> Kencana Village (0 unit)
# SUCCESS -> BUMI SAMARKAND (73 unit)
# SUCCESS -> Bougenville Permai (47 unit)
# SUCCESS -> PERUMAHAN TUNAS MENDALO (42 unit)
# SUCCESS -> ZIVA TAQWA PABAHANAN (0 unit)
# SUCCESS -> Perumahan Rolanda CRB (10 unit)
# SUCCESS -> Graha Nuansa Indramayu (7 unit)
# SUCCESS -> GRESIK MODERN RESIDENCE (15 unit)
# SUCCESS -> GRIYA INDOCENTER (38 unit)
# SUCCESS -> DELONIX GRIYA MARTUBUNG 3 (30 unit)
# SUCCESS -> NAMIYA RESIDENCE (0 unit)
# SUCCESS -> Perumahan Grand Eranes (0 unit)
# SUCCESS -> Ameta Kyoto Residence (0 unit)
# SUCCESS -> ROYAL RESIDENCE TAHAP 2 (0 unit)
# SUCCESS -> PESONA CIBEBER ASRI (0 unit)
# SUCCESS -> Alana Nirwana Residence (0 unit)
# SUCCESS -> Tama Residence Mandan (0 unit)
# SUCCESS -> Romanza Green (0 unit)
# SUCCESS -> TAMAN AMARTHA 5 (0 unit)
# SUCCESS -> THE SCANDI 2 (0 unit)
# SUCCESS -> Bangil Indah Permai 02 (0 unit)
# SUCCESS -> DEHAS II (0 unit)
# SUCCESS -> SURISNA ASRI (0 unit)
