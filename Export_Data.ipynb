# %%
import configparser
import pandas as pd
import mysql.connector
from datetime import datetime

# %%
# Read config
config = configparser.ConfigParser()
config.read("config.ini")

db_config = {
    "host": config["database"]["host"],
    "user": config["database"]["user"],
    "password": config["database"]["password"],
    "database": config["database"]["database"]
}

# %%
# Connect to database
conn = mysql.connector.connect(**db_config)
df = pd.read_sql("SELECT * FROM sikumbang_tapera", conn)
conn.close()

print(f"Loaded {len(df)} rows")
df.head()
# Out:
# C:\Users\fawcet.makay\AppData\Local\Temp\ipykernel_19396\2968145452.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM sikumbang_tapera", conn)
# Loaded 27032 rows
#    id          id_lokasi                  nama_perumahan  \
# 0   1  KLA1320042026T001  PERUMAHAN ATLANTIC 99 TAHAP II
# 1   2  KLA1320042026T001  PERUMAHAN ATLANTIC 99 TAHAP II
# 2   3  KLA1320042026T001  PERUMAHAN ATLANTIC 99 TAHAP II
# 3   4  KLA1320042026T001  PERUMAHAN ATLANTIC 99 TAHAP II
# 4   5  KLA1320042026T001  PERUMAHAN ATLANTIC 99 TAHAP II
#
#                                   alamat        telpon  \
# 0  JL. FX WAKIDI PERUM JATIMULYO PERDANA  081274646776
# 1  JL. FX WAKIDI PERUM JATIMULYO PERDANA  081274646776
# 2  JL. FX WAKIDI PERUM JATIMULYO PERDANA  081274646776
# 3  JL. FX WAKIDI PERUM JATIMULYO PERDANA  081274646776
# 4  JL. FX WAKIDI PERUM JATIMULYO PERDANA  081274646776
#
#                               email website provinsi            kabupaten  \
# 0  atlanticbatuulungguh99@gmail.com          LAMPUNG  KAB LAMPUNG SELATAN
# 1  atlanticbatuulungguh99@gmail.com          LAMPUNG  KAB LAMPUNG SELATAN
# 2  atlanticbatuulungguh99@gmail.com          LAMPUNG  KAB LAMPUNG SELATAN
# 3  atlanticbatuulungguh99@gmail.com          LAMPUNG  KAB LAMPUNG SELATAN
# 4  atlanticbatuulungguh99@gmail.com          LAMPUNG  KAB LAMPUNG SELATAN
#
#     kecamatan  ... kamar_tidur kamar_mandi         atap  \
# 0  Jati Agung  ...           2           1  Baja Ringan
# 1  Jati Agung  ...           2           1  Baja Ringan
# 2  Jati Agung  ...           2           1  Baja Ringan
# 3  Jati Agung  ...           2           1  Baja Ringan
# 4  Jati Agung  ...           2           1  Baja Ringan
#
#                     dinding         lantai     pondasi   createdAt  \
# 0  Bata Merah Plester Acian  Keramik 40x40  Batu belah  2026-05-03
# 1  Bata Merah Plester Acian  Keramik 40x40  Batu belah  2026-05-03
# 2  Bata Merah Plester Acian  Keramik 40x40  Batu belah  2026-05-03
# 3  Bata Merah Plester Acian  Keramik 40x40  Batu belah  2026-05-03
# 4  Bata Merah Plester Acian  Keramik 40x40  Batu belah  2026-05-03
#
#     updatedAt tahun          created_at
# 0  2026-05-03  2026 2026-05-12 22:55:20
# 1  2026-05-03  2026 2026-05-12 22:55:20
# 2  2026-05-03  2026 2026-05-12 22:55:20
# 3  2026-05-03  2026 2026-05-12 22:55:20
# 4  2026-05-03  2026 2026-05-12 22:55:20
#
# [5 rows x 39 columns]

# %%
# Export to CSV
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
filename = f"output/sikumbang_tapera_rumah_{timestamp}.csv"

df.to_csv(filename, index=False, sep="~")
print(f"Exported to {filename}")
# Out:
# Exported to output/sikumbang_tapera_rumah_20260518_055158.csv
